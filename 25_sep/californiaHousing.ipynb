# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import mutual_info_regression
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_california_housing
import plotly.graph_objects as go

# %%
california = fetch_california_housing(as_frame=True)
print(california)
# Out:
# {'data':        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df = pd.concat([california.data, california.target], axis=1)
df.to_csv("housing.csv", index=False)
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
df.dtypes
# Out:
# MedInc         float64
# HouseAge       float64
# AveRooms       float64
# AveBedrms      float64
# Population     float64
# AveOccup       float64
# Latitude       float64
# Longitude      float64
# MedHouseVal    float64
# dtype: object

# %%
numeric_features = df.select_dtypes(include=[np.number])

# %%
df.isna().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %%
numeric_features.corr()
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# ...

# %%
fig = go.Figure()

fig.add_trace(
    go.Heatmap(
        z = numeric_features.corr(),
        x = numeric_features.columns,
        y = numeric_features.columns,
        text = np.around(numeric_features.corr(), decimals=2),
        texttemplate="%{text}",
        colorscale = "oranges"
    )
)

fig.update_layout(
    title="Correlation Heatmap",
    xaxis_nticks=36,
    yaxis_nticks=36,
    width=800,
    height=800,
)

# %%
X_train, X_test, y_train, y_test = train_test_split(california.data, california.target, random_state=4)

# %%
from matplotlib import pyplot as plt
import seaborn as sns


mi = mutual_info_regression(X_train, y_train, random_state=4)
mi_series = pd.Series(mi, index=X_train.columns).sort_values(ascending=False)
display(mi_series.to_frame("mutual_information"))

plt.figure(figsize=(6,4))
sns.barplot(x=mi_series.index, y=mi_series.values)
plt.xticks(rotation=45, ha="right")
plt.title("Mutual Information (regresión) ")
plt.tight_layout()
plt.show()
# Out:
#             mutual_information
# Longitude             0.392246
# MedInc                0.386637
# Latitude              0.361128
# AveRooms              0.099570
# AveOccup              0.077787
# HouseAge              0.029326
# AveBedrms             0.028471
# Population            0.019110
